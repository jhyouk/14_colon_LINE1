# %%
# make SV input file for hg19 circos
# input_id = ["Liver_20Gy1_SO2_retry","S1N2P16_4-7","mm_study2_pancreas_8by1Gy_SO2_retry","HBIR2-1","S1N2P16_4-8","S1N2P15_2-6","mm_study4_fallopian_IR_SO2"]
#input_id = ["HBIR2-1"]

import sys
#input_id = sys.argv[1]  ## python 01_SV_script.py HBIR2-1
input_id = [""]

for input_fn in input_id:
    input_file = file('/home/users/jhyouk/06_mm10_SNUH_radiation/GRCh37/33_SV_annotation/' + input_fn + '.delly.somatic.annotated.filter1.reviewed.vcf')

    output_file = file(input_fn.split('.delly')[0].replace("_retry","") + '_SV.input', 'w')

    input_line = input_file.readline().strip()
    input_line = input_file.readline().strip()

    while input_line:
        input_split = input_line.split('\t')

        input_type = input_split[6]
        input_direction = input_split[5]
        input_color = '.'

        if input_type == 'DEL':
            input_color = 'blue'
        elif input_type == 'DUP':
            input_color = 'green'
        elif input_type == 'INV':
            if input_direction == '3to3':
                input_color = 'red'
            elif input_direction == '5to5':
                input_color = 'orange'
            else:
                print input_fn
                print "no defined direction in INV cases"
                print input_line
                input_line = input_file.readline().strip()
                continue
        elif input_type == 'TRA':
            input_color = 'purple'
        elif input_type == 'INS':
            input_color = 'grey'
        else:
            print input_fn
            print input_line
            input_line = input_file.readline().strip()
            continue
        input_decision = input_split[9].split('_')[0]
        input_thickness = 5
        #if input_decision == 'chromoplexy':
        #    input_thickness = 15

        input_chr1 = 'hs' + input_split[0]
        input_pos1 = int(input_split[1])
        input_chr2 = 'hs' + input_split[2]
        input_pos2 = int(input_split[3])

        output_file.write("%s\t%s\t%s\t%s\t%s\t%s\tcolor=%s,thickness=%sp\n" %(input_chr1,input_pos1,input_pos1,input_chr2,input_pos2,input_pos2,input_color,input_thickness))

        input_line = input_file.readline().strip()

    output_file.close()
    
#output_file1.close()
print 'THE END'

# %%
# input_id = ["Liver_20Gy1_SO2_retry","S1N2P16_4-7","mm_study2_pancreas_8by1Gy_SO2_retry","HBIR2-1","S1N2P16_4-8","S1N2P15_2-6","mm_study4_fallopian_IR_SO2"]
#input_id = ["HBIR2-1"]

import sys
#input_id = sys.argv[1]  ## python 01_SV_script.py HBIR2-1
input_id = ["6371424-Tumor"]

for input_fn in input_id:
    input_file = file('/home/users/jhyouk/6371424-Tumor.delly.somatic.annotated.filter1.reviewed.vcf')

    output_file = file(input_fn + '_SV.input', 'w')

    input_line = input_file.readline().strip()
    input_line = input_file.readline().strip()

    while input_line:
        input_split = input_line.split('\t')

        input_type = input_split[6]
        input_direction = input_split[5]
        input_color = '.'

        if input_type == 'DEL':
            input_color = 'blue'
        elif input_type == 'DUP':
            input_color = 'green'
        elif input_type == 'INV':
            if input_direction == '3to3':
                input_color = 'red'
            elif input_direction == '5to5':
                input_color = 'orange'
            else:
                print input_fn
                print "no defined direction in INV cases"
                print input_line
                input_line = input_file.readline().strip()
                continue
        elif input_type == 'TRA':
            input_color = 'purple'
        elif input_type == 'INS':
            input_color = 'grey'
        else:
            print input_fn
            print input_line
            input_line = input_file.readline().strip()
            continue
        input_decision = input_split[9].split('_')[0]
        input_thickness = 5
        #if input_decision == 'chromoplexy':
        #    input_thickness = 15

        input_chr1 = 'hs' + input_split[0]
        input_pos1 = int(input_split[1])
        input_chr2 = 'hs' + input_split[2]
        input_pos2 = int(input_split[3])

        output_file.write("%s\t%s\t%s\t%s\t%s\t%s\tcolor=%s,thickness=%sp\n" %(input_chr1,input_pos1,input_pos1,input_chr2,input_pos2,input_pos2,input_color,input_thickness))

        input_line = input_file.readline().strip()

    output_file.close()
    
#output_file1.close()
print 'THE END'
# Out:
# THE END

# %%
# SV temp true call selection

import os, sys
temp_list = os.listdir("/home/users/jhyouk/14_colon_LINE1/61_circos/SV")
file_list = []
for i in temp_list:
    if '.txt' in i and 'HC' in i and 'true' not in i:
        file_list.append(i)
        
print len(file_list)

for input_fn in file_list:
    input_file = file("/home/users/jhyouk/14_colon_LINE1/61_circos/SV/"+input_fn)
    output_file = file("/home/users/jhyouk/14_colon_LINE1/61_circos/SV/"+input_fn.replace(".txt","_true.txt"),"w")
    
    input_line = input_file.readline().strip()
    output_file.write(input_line + '\n')
    input_line = input_file.readline().strip()
    
    while input_line:
        input_split = input_line.split('\t')
        if input_split[16] == 'T':
            if input_split[6] == 'DEL' or input_split[6] == 'DUP':
                if int(input_split[8]) >=1000:
                    output_file.write(input_line+'\n')
            else:
                output_file.write(input_line+'\n')
                
        input_line = input_file.readline().strip()
    output_file.close()
    
print 'THE END'
# Out:
# 329
# THE END

# %%
#Merge LINE1 solo, Td and SV calls


import sys, os
info_file = file("/home/users/jhyouk/14_colon_LINE1/colon_LINE1_405_metadata_v2.txt")
info_line = info_file.readline().strip()
info_line = info_file.readline().strip()

sample_list = []
while info_line:
    sample_list.append(info_line.split('\t')[0])
    info_line = info_file.readline().strip()

print len(sample_list)
#sys.exit(1)

td_file = file("/home/users/jhyouk/14_colon_LINE1/61_circos/SV/20210204_Td_list.txt")
t1_file = file("/home/users/hnwoo/Projects/colon_line1/MELTTRANSDUCTION_TRAFICmem_LINE1_somatic_list_dedup_hnwoo_tier1.txt")
t2_file = file("/home/users/hnwoo/Projects/colon_line1/MELTTRANSDUCTION_TRAFICmem_LINE1_somatic_list_dedup_tier2_reviewed_hnwoo.txt")
t3_file = file("/home/users/hnwoo/Projects/colon_line1/MELTTRANSDUCTION_TRAFICmem_LINE1_somatic_list_dedup_hnwoo_tier3.txt")

td_line = td_file.readline().strip()
td_line = td_file.readline().strip()

t1_line = t1_file.readline().strip()
t1_line = t1_file.readline().strip()

t2_line = t2_file.readline().strip()
t2_line = t2_file.readline().strip()

t3_line = t3_file.readline().strip()
t3_line = t3_file.readline().strip()

n=0
for sample_id in sample_list:
    temp_chr = []
    temp_pos = []
    
    pt_num = int(sample_id.split('-')[0].split('C')[1])
    crypt_num = int(sample_id.split('-')[1])
    print sample_id
    #print pt_num
    #print crypt_num
    
    try:
        input_file = file("/home/users/jhyouk/14_colon_LINE1/61_circos/SV/%s_true.txt" % sample_id)
    except:
        output_file = file("/home/users/jhyouk/14_colon_LINE1/61_circos/SV/%s_true.txt" % sample_id,"w")
        output_file.write("#CHR\n")
        output_file.close()
    input_line = input_file.readline().strip()
    input_line = input_file.readline().strip()
    
    output_file = file("/home/users/jhyouk/14_colon_LINE1/61_circos/%s_SV.input" %sample_id,"w")
    
    while td_line:
        td_split = td_line.split('\t')
        temp_pt = int(td_split[0].split('-')[0].split('C')[1])
        temp_crypt = int(td_split[0].split('-')[1])
        #print temp_pt
        #print temp_crypt
        #if sample_id == 'HC03-05':
        #    print td_split
                    
        if pt_num < temp_pt:
            break
        elif pt_num > temp_pt:
            print 'unexpected'
            sys.exit(1)
        else:
            if crypt_num < temp_crypt:
                break
            elif crypt_num > temp_crypt:
                print 'unexpected crypt_num'
                sys.exit(1)
            else:
                if td_split[5] == 'Solo':
                    input_color = 'vlblue'
                    input_thickness = 15
                    temp_chr.append(td_split[3])
                    temp_pos.append(int(td_split[4]))
                    input_chr1 = 'hs' + td_split[3]
                    input_pos1 = int(td_split[4]) - 10
                    input_chr2 = 'hs' + td_split[3]
                    input_pos2 = int(td_split[4])                    
                    
                else:
                    input_color = 'blue'
                    input_thickness = 15
                    temp_chr.append(td_split[3])
                    temp_pos.append(int(td_split[4]))                  
                    input_chr1 = 'hs' + td_split[1]
                    input_pos1 = int(td_split[2])
                    input_chr2 = 'hs' + td_split[3]
                    input_pos2 = int(td_split[4])                      


        output_file.write("%s\t%s\t%s\t%s\t%s\t%s\tcolor=%s,thickness=%sp\n" %(input_chr1,input_pos1,input_pos1,input_chr2,input_pos2,input_pos2,input_color,input_thickness))                   
        td_line = td_file.readline().strip()
    
    #print t1_line
    while t1_line:
        tt=0
        td_split = t1_line.split('\t')
        if td_split[0][0:1] != '1':
            t1_line = t1_file.readline().strip()
            continue
        

        temp_pt = int(td_split[0][1:].split('-')[0].split('C')[1])
        temp_crypt = int(td_split[0][1:].split('-')[1])
        #print temp_pt
        #print temp_crypt
        
        if pt_num < temp_pt:
            break
        elif pt_num > temp_pt:
            print 'unexpected'
            sys.exit(1)
        else:
            if crypt_num < temp_crypt:
                break
            elif crypt_num > temp_crypt:
                print 'unexpected crypt_num'
                sys.exit(1)
            else:
                #print 'yes'
                for i in temp_pos:
                    if abs(i-int(td_split[3])) < 500:
                        if td_split[2] == temp_chr[temp_pos.index(i)]:
                            t1_line = t1_file.readline().strip()
                            tt=1
                            break
                if tt==1:
                    continue
                
                input_color = 'vlblue'
                input_thickness = 15
                temp_chr.append(td_split[2])
                temp_pos.append(int(td_split[3]))

                input_chr1 = 'hs' + td_split[2]
                input_pos1 = int(td_split[3]) - 10
                input_chr2 = 'hs' + td_split[2]
                input_pos2 = int(td_split[3])                  
        output_file.write("%s\t%s\t%s\t%s\t%s\t%s\tcolor=%s,thickness=%sp\n" %(input_chr1,input_pos1,input_pos1,input_chr2,input_pos2,input_pos2,input_color,input_thickness))                   
                
        t1_line = t1_file.readline().strip()       
        
    while t2_line:
        tt=0
        td_split = t2_line.split('\t')
        if td_split[0][0:1] != '1':
            t2_line = t2_file.readline().strip()
            continue
            
        temp_pt = int(td_split[0][1:].split('-')[0].split('C')[1])
        temp_crypt = int(td_split[0][1:].split('-')[1])
        
        if pt_num < temp_pt:
            break
        elif pt_num > temp_pt:
            print 'unexpected'
            sys.exit(1)
        else:
            if crypt_num < temp_crypt:
                break
            elif crypt_num > temp_crypt:
                print 'unexpected crypt_num'
                sys.exit(1)
            else:
                for i in temp_pos:
                    if abs(i-int(td_split[3])) < 500:
                        if td_split[2] == temp_chr[temp_pos.index(i)]:
                            t2_line = t2_file.readline().strip()
                            tt=1
                            break
                if tt==1:
                    continue
                
                input_color = 'vlblue'
                input_thickness = 15
                temp_chr.append(td_split[2])
                temp_pos.append(int(td_split[3]))

                input_chr1 = 'hs' + td_split[2]
                input_pos1 = int(td_split[3]) - 10
                input_chr2 = 'hs' + td_split[2]
                input_pos2 = int(td_split[3])                  
        output_file.write("%s\t%s\t%s\t%s\t%s\t%s\tcolor=%s,thickness=%sp\n" %(input_chr1,input_pos1,input_pos1,input_chr2,input_pos2,input_pos2,input_color,input_thickness))                   
                
        t2_line = t2_file.readline().strip()              
        
        
    while t3_line:
        tt=0
        td_split = t3_line.split('\t')
        if td_split[0][0:1] != '1':
            t3_line = t3_file.readline().strip()
            continue
            
        temp_pt = int(td_split[0][1:].split('-')[0].split('C')[1])
        temp_crypt = int(td_split[0][1:].split('-')[1])
        
        if pt_num < temp_pt:
            break
        elif pt_num > temp_pt:
            print 'unexpected'
            sys.exit(1)
        else:
            if crypt_num < temp_crypt:
                break
            elif crypt_num > temp_crypt:
                print 'unexpected crypt_num'
                sys.exit(1)
            else:
                for i in temp_pos:
                    if abs(i-int(td_split[3])) < 500:
                        if td_split[2] == temp_chr[temp_pos.index(i)]:
                            t3_line = t3_file.readline().strip()
                            tt=1
                            break
                if tt == 1:
                    continue
                
                input_color = 'vlblue'
                input_thickness = 15
                temp_chr.append(td_split[2])
                temp_pos.append(int(td_split[3]))

                input_chr1 = 'hs' + td_split[2]
                input_pos1 = int(td_split[3]) - 10
                input_chr2 = 'hs' + td_split[2]
                input_pos2 = int(td_split[3])                  
        output_file.write("%s\t%s\t%s\t%s\t%s\t%s\tcolor=%s,thickness=%sp\n" %(input_chr1,input_pos1,input_pos1,input_chr2,input_pos2,input_pos2,input_color,input_thickness))                   
                
        t3_line = t3_file.readline().strip()              
     
    while input_line:
        tt=0
        input_split = input_line.split('\t')
        for i in temp_pos:
            if abs(i-int(input_split[1])) < 500:
                if input_split[0] == temp_chr[temp_pos.index(i)]:
                    input_line = input_file.readline().strip()
                    tt=1
                    break
            elif abs(i-int(input_split[3])) < 500:
                #print 'yes'
                #print input_split[2]
                #print temp_chr[temp_pos.index(i)]
                if input_split[2] == temp_chr[temp_pos.index(i)]:
                    input_line = input_file.readline().strip()
                    tt=1
                    break
        if tt == 1:            
            continue
                    
                    
        input_type = input_split[6]
        input_direction = input_split[5]
        input_color = '.'

        if input_type == 'DEL':
            input_color = 'black'
        elif input_type == 'DUP':
            input_color = 'green'
        elif input_type == 'INV':
            if input_direction == '3to3':
                input_color = 'red'
            elif input_direction == '5to5':
                input_color = 'orange'
            else:
                print input_fn
                print "no defined direction in INV cases"
                print input_line
                input_line = input_file.readline().strip()
                continue
        elif input_type == 'TRA':
            input_color = 'purple'
        elif input_type == 'INS':
            input_color = 'grey'
        else:
            print input_fn
            print input_line
            input_line = input_file.readline().strip()
            continue
        input_decision = input_split[9].split('_')[0]
        input_thickness = 5

        input_chr1 = 'hs' + input_split[0]
        input_pos1 = int(input_split[1])
        input_chr2 = 'hs' + input_split[2]
        input_pos2 = int(input_split[3])

        output_file.write("%s\t%s\t%s\t%s\t%s\t%s\tcolor=%s,thickness=%sp\n" %(input_chr1,input_pos1,input_pos1,input_chr2,input_pos2,input_pos2,input_color,input_thickness))

        input_line = input_file.readline().strip()

    output_file.close()

print 'THE END'
# Out:
# 405
# HC01-01
# HC01-02
# HC01-03
# HC01-04
# HC01-05
# HC01-06
# HC01-07
# HC01-08
# HC01-09
# HC01-10
# HC01-11
# HC01-12
# HC01-13
# HC01-14
# HC01-15
# HC01-16
# HC01-17
# HC01-18
# HC01-19
# HC01-20
# HC01-21
# HC01-22
# HC01-23
# HC02-01
# HC02-02
# HC02-03
# HC02-04
# HC02-05
# HC02-06
# HC02-07
# HC02-08
# HC02-09
# HC02-10
# HC02-11
# HC02-12
# HC02-13
# HC02-14
# HC02-15
# HC02-16
# HC02-17
# HC02-18
# HC02-19
# HC02-20
# HC02-21
# HC02-22
# HC03-01
# HC03-02
# HC03-03
# HC03-04
# HC03-05
# HC03-06
# HC03-07
# HC03-08
# HC03-09
# HC03-10
# HC03-11
# HC03-12
# HC03-13
# HC03-14
# HC03-15
# HC03-16
# HC03-17
# HC03-18
# HC03-19
# HC03-20
# HC03-21
# HC03-22
# HC03-23
# HC03-24
# HC04-01
# HC04-02
# HC04-03
# HC04-04
# HC04-05
# HC04-06
# HC04-07
# HC04-08
# HC04-09
# HC04-10
# HC04-11
# HC04-12
# HC04-13
# HC04-14
# HC04-15
# HC04-16
# HC04-17
# HC04-18
# HC04-19
# HC04-20
# HC04-21
# HC04-22
# HC04-23
# HC05-01
# HC05-02
# HC05-03
# HC05-04
# HC05-05
# HC05-06
# HC05-07
# ...

# %%
import sys, os
info_file = file("/home/users/jhyouk/14_colon_LINE1/colon_LINE1_405_metadata_v2.txt")
info_line = info_file.readline().strip()
info_line = info_file.readline().strip()

sample_list = []
while info_line:
    sample_list.append(info_line.split('\t')[0])
    info_line = info_file.readline().strip()

print len(sample_list)

for input_fn in sample_list:
    input_file = file('/home/users/jhyouk/14_colon_LINE1/61_circos/'+ input_fn + '_SV.input')
    output_file = file('/home/users/jhyouk/14_colon_LINE1/61_circos/%s_linkends.txt' % input_fn,"w")
    
    input_line = input_file.readline().strip()
    while input_line:
        if 'color=blue' in input_line:
            input_split = input_line.split('\t')
            output_file.write(input_split[3] + '\t' +input_split[4] + '\t' + input_split[5] + '\t0\n')
        input_line = input_file.readline().strip()
    
    output_file.close()
print 'THE END'
# Out:
# 405
# THE END

# %%
# Transduction only per patient

import sys, os
pre_list = os.listdir("/home/users/jhyouk/14_colon_LINE1/61_circos")
file_list = []
for i in pre_list:
    if '_SV.input' in i and '_sum' not in i:
        file_list.append(i)
print len(file_list)
#sys.exit(1)

id_list = ['HC01','HC02','HC03','HC04','HC05','HC06','HC08','HC09','HC10','HC12','HC13','HC14','HC15','HC16','HC17','HC18','HC19','HC20','HC21'] #'HC15'
print len(id_list)

for id_fn in id_list:
    print id_fn
    output_file = file("/home/users/jhyouk/14_colon_LINE1/61_circos/%s_sum_SV.input" % id_fn,"w")
    output_file1 = file("/home/users/jhyouk/14_colon_LINE1/61_circos/%s_sum_linkends.txt" % id_fn,"w")

    #output_file1 = file("/home/users/jhyouk/14_colon_LINE1/61_circos/%s_sum_CNV.input" % id_fn,"w")
    #output_file2 = file("/home/users/jhyouk/14_colon_LINE1/61_circos/%s_sum_linkends.txt" % id_fn,"w")
    #output_file3 = file("/home/users/jhyouk/14_colon_LINE1/61_circos/%s_sum_SNV.input" % id_fn,"w")
#    output_file4 = file("/home/users/jhyouk/14_colon_LINE1/61_circos/%s_sum_CNV.input" % id_fn,"w")

    temp_list = []
    for j in file_list:
        if id_fn in j:
            temp_list.append(j)
    #n=0
    for input_fn in temp_list:
        input_file = file("/home/users/jhyouk/14_colon_LINE1/61_circos/" + input_fn)
        input_line = input_file.readline().strip()
        while input_line:
            input_split = input_line.split('\t')
            if 'blue' in input_line and 'vlblue' not in input_line:
                output_file.write(input_line.replace("thickness=15p","thickness=5p")+'\n')
                output_file1.write(input_split[3] + '\t' +input_split[4] + '\t' + input_split[5] + '\t0\n')
                #print input_line
                #n+=1
                #if n>10:
                #    sys.exit(1)
                    
            input_line = input_file.readline().strip()
        input_file.close()
    output_file.close()
    output_file1.close()
print 'THE END'
# Out:
# 405
# 19
# HC01
# HC02
# HC03
# HC04
# HC05
# HC06
# HC08
# HC09
# HC10
# HC12
# HC13
# HC14
# HC15
# HC16
# HC17
# HC18
# HC19
# HC20
# HC21
# THE END

# %%
# Transduction only for total patients (n=19)

import sys, os
pre_list = os.listdir("/home/users/jhyouk/14_colon_LINE1/61_circos")
file_list = []
for i in pre_list:
    if '_SV.input' in i and '_sum' not in i:
        file_list.append(i)
print len(file_list)
#sys.exit(1)

id_list = ['HC01','HC02','HC03','HC04','HC05','HC06','HC08','HC09','HC10','HC12','HC13','HC14','HC15','HC16','HC17','HC18','HC19','HC20','HC21'] #'HC15'
print len(id_list)

output_file = file("/home/users/jhyouk/14_colon_LINE1/61_circos/total_sum_SV.input","w")
output_file1 = file("/home/users/jhyouk/14_colon_LINE1/61_circos/total_sum_linkends.txt","w")

for id_fn in id_list:
    print id_fn

    temp_list = file_list

    #n=0
    for input_fn in temp_list:
        if id_fn in input_fn:
            input_file = file("/home/users/jhyouk/14_colon_LINE1/61_circos/" + input_fn)
            input_line = input_file.readline().strip()
            while input_line:
                input_split = input_line.split('\t')
                if 'blue' in input_line and 'vlblue' not in input_line:
                    output_file.write(input_line.replace("thickness=15p","thickness=5p")+'\n')
                    output_file1.write(input_split[3] + '\t' +input_split[4] + '\t' + input_split[5] + '\t0\n')
                    #print input_line
                    #n+=1
                    #if n>10:
                    #    sys.exit(1)

                input_line = input_file.readline().strip()
            input_file.close()
output_file.close()
output_file1.close()
print 'THE END'
# Out:
# 405
# 19
# HC01
# HC02
# HC03
# HC04
# HC05
# HC06
# HC08
# HC09
# HC10
# HC12
# HC13
# HC14
# HC15
# HC16
# HC17
# HC18
# HC19
# HC20
# HC21
# THE END

# %%
import sys, os
pre_list = os.listdir("/home/users/jhyouk/14_colon_LINE1/61_circos")
file_list = []
for i in pre_list:
    if 'total_sum_SV.input' in i:
        file_list.append(i)
print len(file_list)
#sys.exit(1)
m=0
input_file = file("/home/users/jhyouk/14_colon_LINE1/61_circos/total_sum_SV.input")
input_line = input_file.readline().strip()
source_dic = []
n_dic = []
while input_line:
    input_split = input_line.split('\t')
    input_id = input_split[0] + ':' + input_split[1]
    if input_id not in source_dic:
        source_dic.append(input_id)
        n_dic.append(1)
    else:
        n_dic[source_dic.index(input_id)] += 1
    input_line = input_file.readline().strip()
    
for i in range(0,len(source_dic)):
    m+= n_dic[i]
    print source_dic[i] + '=' + str(n_dic[i]) +'\n'
print m
# Out:
# 1
# hs1:63705395=3
#
# hs12:3608320=16
#
# hs9:111566930=1
#
# hs1:23718274=1
#
# hs15:56252863=1
#
# hs22:29065076=32
#
# hs2:180851445=1
#
# hs8:66304205=1
#
# hsX:11731469=17
#
# hs13:30215747=1
#
# hs7:90330642=2
#
# hs14:71198154=1
#
# hs7:117443780=1
#
# hs14:59220698=4
#
# hs1:119401188=6
#
# hs12:71020342=2
#
# hs6:13191197=1
#
# hs9:35646856=1
#
# hs14:31150833=2
#
# hs14:59220387=1
#
# hs14:71210888=1
#
# hs12:117814452=1
#
# hs17:77724841=4
#
# hs12:2998270=1
#
# hs14:34136250=2
#
# hs12:117810993=1
#
# hs14:24572902=1
#
# hs7:90331920=2
#
# hs3:55788569=1
#
# hs3:151148550=1
#
# hs12:53845500=1
#
# hs6:107018187=1
#
# hs7:90330294=1
#
# hs6:13191112=1
#
# hs6:13191016=2
#
# hs1:119401143=1
#
# hs1:93512259=1
#
# hs13:30213073=1
#
# hs1:162014860=2
#
# hs2:130697935=1
#
# 122
