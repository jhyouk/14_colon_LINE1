# %%
# reconstruction of early embryonic phylogeny using sypark's script

#01
import os,sys
temp_list = os.listdir("/home/users/jhyouk/14_colon_LINE1/51_haplotypecaller")
file_list = []
pre_list = []
for i in temp_list:
    if 'HC15-' not in i and '.out' not in i and '.idx' not in i and 'indel' not in i and '.sh' not in i and 'ipyn' not in i and 'snp' in i and 'HC02-01' not in i:
        pre_list.append(i)
print len(pre_list)
#for i in pre_list:
#    print i
#sys.exit(1)
output_file = file("/home/users/jhyouk/14_colon_LINE1/53_early_embryonic_tree_bySYPark/51_run_intersect_381.sh","w")

for input_fn in pre_list:
    input_fn = input_fn.split('.')[0]
    output_file.write("python vcf_intersection.py /home/users/jhyouk/14_colon_LINE1/52_germline_varscan/%s.varscan.snp.vcf /home/users/jhyouk/14_colon_LINE1/51_haplotypecaller/%s.hc.snp.vcf %s VS HC &> %s.ints.log && mv %s.ints.log %s.ints.success\n" %(input_fn,input_fn,input_fn,input_fn,input_fn,input_fn))

#HC01-21.hc.snp.indel.vcf
#HC01-01.varscan.snp.vcf
output_file.close()
print 'THE END'
# Out:
# 381
# THE END

# %%
#02
#python extract_variants_in_all_samples.py HC15_23s_common_list.txt HC15_23s_common_ids.txt HC15_subs_in_all_23s.txt 23 &> ext_var.log && mv ext_var.log ext_var.success

#id_list = ['HC01','HC02','HC03','HC04','HC05','HC06','HC08','HC09','HC10','HC12','HC13','HC14','HC16','HC17','HC18','HC19','HC20','HC21'] #'HC15'
id_list = ['HC02']
n=0

import os,sys
temp_list = os.listdir("/home/users/jhyouk/14_colon_LINE1/53_early_embryonic_tree_bySYPark")
file_list = []
pre_list = []
for i in temp_list:
    if 'HC02-' in i and '.VS_HC_common' in i and 'cmn' not in i:
        pre_list.append(i)
print len(pre_list)
#sys.exit(1)

output_file = file("/home/users/jhyouk/14_colon_LINE1/53_early_embryonic_tree_bySYPark/52_run_ext_subs_in_all_HC02_22s.sh","w")
for i in id_list:
    print i
    m=0
    output_file1 = file("/home/users/jhyouk/14_colon_LINE1/53_early_embryonic_tree_bySYPark/%s_common_list.txt" %i,"w")
    output_file2 = file("/home/users/jhyouk/14_colon_LINE1/53_early_embryonic_tree_bySYPark/%s_common_ids.txt" %i,"w")

    for j in pre_list:
        if i in j:
            m+=1
            input_fn = j.split('.')[0]
            output_file1.write(j+'\n')
            output_file2.write(input_fn+'\n')
    output_file1.close()
    output_file2.close()
    n+=m
    output_file.write("python extract_variants_in_all_samples.py %s_common_list.txt %s_common_ids.txt %s_subs_in_all.txt %s &> %s_ext_var.log && mv %s_ext_var.log %s_ext_var.success\n" %(i,i,i,str(m),i,i,i))
print n    
    


output_file.close()
print 'THE END'
# Out:
# 22
# HC02
# 22
# THE END

# %%
#03
#python remove_common_variants.py HC15_23s_common_list.txt HC15_subs_in_all_23s.txt &> rm_cmn.log && mv rm_cmn.log rm_cmn.success

id_list = ['HC01','HC02','HC03','HC04','HC05','HC06','HC08','HC09','HC10','HC12','HC13','HC14','HC16','HC17','HC18','HC19','HC20','HC21'] #'HC15'
output_file = file("/home/users/jhyouk/14_colon_LINE1/53_early_embryonic_tree_bySYPark/53_remove_common_sub_381.sh","w")
for i in id_list:
    output_file.write("python remove_common_variants.py %s_common_list.txt %s_subs_in_all.txt &> %s_rm_cmn.log && mv %s_rm_cmn.log %s_rm_cmn.success\n" %(i,i,i,i,i))
    
output_file.close()
print 'THE END'
# Out:
# THE END

# %%
#04

import os,sys
temp_list = os.listdir("/home/users/jhyouk/14_colon_LINE1/53_early_embryonic_tree_bySYPark")
file_list = []
pre_list = []
for i in temp_list:
    if 'HC02-' in i and '.cmn_fi' in i and 'readinfo.readc.rasm2' not in i:
        pre_list.append(i)
print len(pre_list)
#for i in pre_list:
#    print i
#sys.exit(1)

info_file = file("/home/users/jhyouk/14_colon_LINE1/colon_LINE1_405_metadata_v2.txt")
info_line = info_file.readline().strip()
info_line = info_file.readline().strip()

info_dic = {}
while info_line:
    info_split = info_line.split('\t')
    info_dic[info_split[0]] = info_split[1]

    info_line = info_file.readline().strip()

print(len(info_dic))


output_file = file("/home/users/jhyouk/14_colon_LINE1/53_early_embryonic_tree_bySYPark/54_run_readinfo_annot_HC02_22s.sh","w")

for input_fn in pre_list:
    input_fn = input_fn.split('.')[0]
    output_file.write("python point_mutation_annotation_serial_run.py -i %s.VS_HC_common.cmn_fi -t /home/users/team_projects/colon_LINE1/02_bam/%s\
 -n /home/users/team_projects/colon_LINE1/02_bam/HC15_germline_30x.s.md.bam &> %s.ri_annot.log &&\
 mv %s.ri_annot.log %s.ri_annot.success\n" %(input_fn,info_dic[input_fn],input_fn,input_fn,input_fn))


    
output_file.close()
print 'THE END'





#python point_mutation_annotation_serial_run.py -i 10_ALL13-4_006H8.VS_HC_common.cmn_fi -t /home/users/team_projects/Lineage_tracing/DB10/02_BAM/10_ALL13-4_006H8.s.md.ir.br.bam -n /home/users/team_projects/Lineage_tracing/DB2/02_BAM/2_blood_3s_merged.s.md.ir.br.bam &> 10_ALL13-4_006H8.ri_annot.log && mv 10_ALL13-4_006H8.ri_annot.log 10_ALL13-4_006H8.ri_annot.success
# Out:
# 22
# 405
# THE END

# %%
#05
#id_list = ['HC01','HC15','HC03','HC04','HC05','HC06','HC08','HC09','HC10','HC12','HC13','HC14','HC16','HC17','HC18','HC19','HC20','HC21'] #'HC15'
id_list = ['HC02']

import os,sys
temp_list = os.listdir("/home/users/jhyouk/14_colon_LINE1/53_early_embryonic_tree_bySYPark")
file_list = []
pre_list = []
for i in temp_list:
    if 'HC02-' in i and 'rasm2' in i:
        pre_list.append(i)
print len(pre_list)
#for i in pre_list:
#    print i
#sys.exit(1)

#info_file = file("/home/users/jhyouk/14_colon_LINE1/colon_LINE1_405_metadata_v2.txt")
#info_line = info_file.readline().strip()
#info_line = info_file.readline().strip()
#
#info_dic = {}
#while info_line:
#    info_split = info_line.split('\t')
#    info_dic[info_split[0]] = info_split[1]

#    info_line = info_file.readline().strip()

#print(len(info_dic))


output_file = file("/home/users/jhyouk/14_colon_LINE1/53_early_embryonic_tree_bySYPark/55_run_np_annot_HC02_22s.sh","w")

for input_fn in pre_list:
    input_fn = input_fn.split('.')[0]
    output_file.write("sh ./SNV_NormalPanel_Serial_Annotation_modified.sh %s.VS_HC_common.cmn_fi.readinfo.readc.rasm2 \
&> %s.np_annot.log && mv %s.np_annot.log %s.np_annot.success\n" %(input_fn,input_fn,input_fn,input_fn))

    
output_file.close()
print 'THE END'
# Out:
# 22
# THE END

# %%
#06

id_list = ['HC01','HC15','HC03','HC04','HC05','HC06','HC08','HC09','HC10','HC12','HC13','HC14','HC16','HC17','HC18','HC19','HC20','HC21'] #'HC15'
#id_list = ['HC02']

import os,sys
temp_list = os.listdir("/home/users/jhyouk/14_colon_LINE1/53_early_embryonic_tree_bySYPark")
file_list = []
pre_list = []
for i in temp_list:
    if 'HC02-' not in i and '.snuN30.bgiN24' in i:
        pre_list.append(i)
print len(pre_list)
#for i in pre_list:
#    print i
#sys.exit(1)

#info_file = file("/home/users/jhyouk/14_colon_LINE1/colon_LINE1_405_metadata_v2.txt")
#info_line = info_file.readline().strip()
#info_line = info_file.readline().strip()
#
#info_dic = {}
#while info_line:
#    info_split = info_line.split('\t')
#    info_dic[info_split[0]] = info_split[1]

#    info_line = info_file.readline().strip()

#print(len(info_dic))


output_file = file("/home/users/jhyouk/14_colon_LINE1/53_early_embryonic_tree_bySYPark/56_run_anv_383s.sh","w")

for input_fn in pre_list:
    input_id = input_fn.split('.')[0]
    output_file.write("python annotate_using_annovar_v2.py %s -i 'refGene,1000g2015aug_all,1000g2015aug_eas,exac03,esp6500siv2_all,\
avsnp150,cosmic86_coding' &> %s.anv.log && mv %s.anv.log %s.anv.success\n" %(input_fn,input_id,input_id,input_id))

    
output_file.close()
print 'THE END'
# Out:
# 383
# THE END

# %%
#07
id_list = ['HC01','HC15','HC03','HC04','HC05','HC06','HC08','HC09','HC10','HC12','HC13','HC14','HC16','HC17','HC18','HC19','HC20','HC21'] #'HC15'
#id_list = ['HC02']

import os,sys
temp_list = os.listdir("/home/users/jhyouk/14_colon_LINE1/53_early_embryonic_tree_bySYPark")
file_list = []
pre_list = []
for i in temp_list:
    if 'HC02-' not in i and '.VS_HC_common.cmn_fi.readinfo.readc.rasm2.snuN30.bgiN24.anv' in i and '.fi' not in i:
        pre_list.append(i)
print len(pre_list)
#for i in pre_list:
#    print i
#sys.exit(1)

#info_file = file("/home/users/jhyouk/14_colon_LINE1/colon_LINE1_405_metadata_v2.txt")
#info_line = info_file.readline().strip()
#info_line = info_file.readline().strip()
#
#info_dic = {}
#while info_line:
#    info_split = info_line.split('\t')
#    info_dic[info_split[0]] = info_split[1]

#    info_line = info_file.readline().strip()

#print(len(info_dic))


output_file = file("/home/users/jhyouk/14_colon_LINE1/53_early_embryonic_tree_bySYPark/57_run_1st_filter_383s_1.sh","w")

n = 0
m=1
for input_fn in pre_list:
    n+=1
    if n % 30 == 0:
        m+=1
        output_file.close()
        output_file = file("/home/users/jhyouk/14_colon_LINE1/53_early_embryonic_tree_bySYPark/57_run_1st_filter_383s_%s.sh" % str(m),"w")

        
    input_id = input_fn.split('.')[0]
    output_file.write("python DB_1st_filter_standard.py %s 151\n" %(input_fn))

    
output_file.close()
print 'THE END'
# Out:
# 383
# THE END

# %%
#08

id_list = ['HC01','HC15','HC03','HC04','HC05','HC06','HC08','HC09','HC10','HC12','HC13','HC14','HC16','HC17','HC18','HC19','HC20','HC21'] #'HC15'
#id_list = ['HC02']
n=0

import os,sys
temp_list = os.listdir("/home/users/jhyouk/14_colon_LINE1/53_early_embryonic_tree_bySYPark")
file_list = []
pre_list = []
for i in temp_list:
    if 'HC02-' not in i and '.VS_HC_common.cmn_fi.readinfo.readc.rasm2.snuN30.bgiN24.anv.fi' in i:
        pre_list.append(i)
print len(pre_list)
#sys.exit(1)

output_file = file("/home/users/jhyouk/14_colon_LINE1/53_early_embryonic_tree_bySYPark/58_run_merge_list_383s.sh","w")
for i in id_list:
    print i
    m=0
    output_file1 = file("/home/users/jhyouk/14_colon_LINE1/53_early_embryonic_tree_bySYPark/%s_merge_input_list.txt" %i,"w")
    output_file2 = file("/home/users/jhyouk/14_colon_LINE1/53_early_embryonic_tree_bySYPark/%s_merge_input_ids.txt" %i,"w")

    for j in pre_list:
        if i in j:
            m+=1
            input_fn = j.split('.')[0]
            output_file1.write(j+'\n')
            output_file2.write(input_fn+'\n')
    output_file1.close()
    output_file2.close()
    n+=m
    output_file.write("python vcfs_merge_casenum_caseid_fast.py %s_merge_input_list.txt %s_merge_input_ids.txt %s_merged.txt\n" %(i,i,i))
print n    
    


output_file.close()
print 'THE END'
# Out:
# 383
# HC01
# HC15
# HC03
# HC04
# HC05
# HC06
# HC08
# HC09
# HC10
# HC12
# HC13
# HC14
# HC16
# HC17
# HC18
# HC19
# HC20
# HC21
# 383
# THE END

# %%
## Extra. production of merged_mpu per each patient
import os,sys
id_list = ['HC01','HC15','HC03','HC04','HC05','HC06','HC08','HC09','HC10','HC12','HC13','HC14','HC16','HC17','HC18','HC19','HC20','HC21'] #'HC15'
#id_list = ['HC02']

info_file = file("/home/users/jhyouk/14_colon_LINE1/colon_LINE1_405_metadata_v2.txt")
info_line = info_file.readline().strip()
info_line = info_file.readline().strip()

info_dic = {}
while info_line:
    info_split = info_line.split('\t')
    info_dic[info_split[0]] = info_split[1]

    info_line = info_file.readline().strip()

print(len(info_dic))

output_file = file("/home/users/jhyouk/14_colon_LINE1/03_mpileup/merged_mpileup/01_run.383.mpu.call.sh","w")

for pt_num in id_list:
    print pt_num
    crypt_num = 0
    temp_list = os.listdir("/home/users/jhyouk/14_colon_LINE1/53_early_embryonic_tree_bySYPark")
    file_list = []
    pre_list = []
    for i in temp_list:
        if pt_num in i and '.VS_HC_common' in i and '.cmn_fi' not in i:
            pre_list.append(i)
    print len(pre_list)
    crypt_num = str(len(pre_list))
    #sys.exit(1)
    #for i in pre_list:
    #    print i

    #output_file = file("/home/users/jhyouk/14_colon_LINE1/03_mpileup/merged_mpileup/01_run.%s.%s.mpu.call.sh" %(pt_num,crypt_num),"w")
    bam_list = ''
    for input_fn in pre_list:
        input_id = input_fn.split('.')[0]
        bam_list = bam_list + '/home/users/team_projects/colon_LINE1/02_bam/'+ info_dic[input_id] + ' '
    #print bam_list
    #sys.exit(1)

    for ii in range(1,26):
        chr_num = str(ii).replace('23','X').replace("24","Y").replace("25","MT")
        output_file.write("(samtools mpileup -AB -d 10000 -q 20 -Q 20 -f /home/users/data/01_reference/human_g1k_v37/human_g1k_v37.fasta -r \
# %s %s| gzip > %s.%ss.q20Q20.chr%s.mpileup.gz) 2> %s.mpu.chr%s.log && mv %s.mpu.chr%s.log %s.mpu.chr%s.success \
&& python /home/users/sypark/01_Python_files/normal_matrix/pileup_calling_snv.py %s.%ss.q20Q20.chr%s.mpileup.gz %s \
&> %s.chr%s.snv_call.log && mv %s.chr%s.snv_call.log %s.chr%s.snv_call.success && \
python /home/users/sypark/01_Python_files/normal_matrix/pileup_calling_indel_190705.py %s.%ss.q20Q20.chr%s.mpileup.gz %s \
&> %s.chr%s.indel_call.log && mv %s.chr%s.indel_call.log %s.chr%s.indel_call.success\n" \
%(chr_num,bam_list,pt_num,crypt_num,chr_num,pt_num,chr_num,pt_num,chr_num,pt_num,chr_num,\
pt_num,crypt_num,chr_num,crypt_num,\
pt_num,chr_num,pt_num,chr_num,pt_num,chr_num,\
pt_num,crypt_num,chr_num,crypt_num,\
pt_num,chr_num,pt_num,chr_num,pt_num,chr_num))

    #(samtools mpileup -AB -d 10000 -q 20 -Q 20 -f /home/users/data/01_reference/human_g1k_v37/human_g1k_v37.fasta -r %s \
    #10_ALL13-4_006H8.s.md.ir.br.bam 10_ALL13-8_001G5.s.md.ir.br.bam 10_ALL17-3_001D3.s.md.ir.br.bam 10_ALL17-5_002B3.s.md.ir.br.bam 10_ALL19-2_001B5.s.md.ir.br.bam 10_ARL10-4_001D4-B6.s.md.ir.br.bam 10_ARL10-4_001D4.s.md.ir.br.bam 10_ARL12-1_001B3.s.md.ir.br.bam 10_ARL12-2_001C12.s.md.ir.br.bam 10_ARL12-4_001H11.s.md.ir.br.bam 10_ARL1-3_003G11.s.md.ir.br.bam 10_ARL13-1_001G8.s.md.ir.br.bam 10_ARL1-5_003B3.s.md.ir.br.bam 10_ARL23-6_002E11.s.md.ir.br.bam 10_ARL3-2_006B8.s.md.ir.br.bam 10_ARL6-1_001A9.s.md.ir.br.bam 10_ARL6-2_001E7.s.md.ir.br.bam 10_ARL7-2_005B2.s.md.ir.br.bam 10_ARL8-4_001D12.s.md.ir.br.bam 10_ARL9-2_005G8.s.md.ir.br.bam 10_ARL9-3_001D5.s.md.ir.br.bam 10_ARLFb2-5_002G8.s.md.ir.br.bam 10_Blood_3s_merged.s.md.ir.br.bam 10_LA14-2_001E7.s.md.ir.br.bam 10_LA14-2_002D1-A5.s.md.ir.br.bam 10_LA14-2_002D1.s.md.ir.br.bam 10_LA15-2_001D7.s.md.ir.br.bam 10_LAFb11-3_001G8.s.md.ir.br.bam 10_LAFb16-2_001D8.s.md.ir.br.bam 10_LAFb16-3_001E11.s.md.ir.br.bam 10_LAFb8-2_001D4.s.md.ir.br.bam 10_PLL2-2_001F4.s.md.ir.br.bam 10_PLL4-4_003F8.s.md.ir.br.bam 10_PLL6-3_002A11.s.md.ir.br.bam 10_PLL6-3_002D6.s.md.ir.br.bam 10_PRL10-2_001G10.s.md.ir.br.bam 10_PRL10-3_001G7.s.md.ir.br.bam 10_PRL10-5_001E2.s.md.ir.br.bam 10_PRL12-5_001C5.s.md.ir.br.bam 10_PRL16-1_001E6.s.md.ir.br.bam 10_PRL2-4_002C4.s.md.ir.br.bam 10_PRL3-1_001B8-E10.s.md.ir.br.bam 10_PRL3-1_001B8.s.md.ir.br.bam 10_PRL3-1_001E4.s.md.ir.br.bam 10_PRL3-2_002E11.s.md.ir.br.bam 10_PRL3-3_001B11.s.md.ir.br.bam 10_PRL4-1_004C1.s.md.ir.br.bam 10_PRL4-4_001E8.s.md.ir.br.bam 10_PRLM2-3_001D10.s.md.ir.br.bam 10_RA9-3_005G11.s.md.ir.br.bam 10_RA9-4_005B8.s.md.ir.br.bam 10_UO3-2_001C6.s.md.ir.br.bam
    # | gzip > DB10.52s.q20Q20.chr5.mpileup.gz) 2> DB10.mpu.chr5.log && mv DB10.mpu.chr5.log DB10.mpu.chr5.success && python /home/users/sypark/01_Python_files/normal_matrix/pileup_calling_snv.py DB10.52s.q20Q20.chr5.mpileup.gz 52 &> DB10.chr5.snv_call.log && mv DB10.chr5.snv_call.log DB10.chr5.snv_call.success && python /home/users/sypark/01_Python_files/normal_matrix/pileup_calling_indel_190705.py DB10.52s.q20Q20.chr5.mpileup.gz 52 &> DB10.chr5.indel_call.log && mv DB10.chr5.indel_call.log DB10.chr5.indel_call.success

output_file.close()
print 'THE END'
# Out:
# 405
# HC01
# 23
# HC15
# 23
# HC03
# 24
# HC04
# 23
# HC05
# 24
# HC06
# 22
# HC08
# 23
# HC09
# 21
# HC10
# 20
# HC12
# 22
# HC13
# 22
# HC14
# 19
# HC16
# 18
# HC17
# 14
# HC18
# 17
# HC19
# 23
# HC20
# 22
# HC21
# 23
# THE END

# %%
#09
info_file = file("/home/users/jhyouk/14_colon_LINE1/colon_LINE1_405_metadata_v2.txt")
info_line = info_file.readline().strip()
info_line = info_file.readline().strip()

info_dic = {}
while info_line:
    info_split = info_line.split('\t')
    info_dic[info_split[0]] = info_split[1]

    info_line = info_file.readline().strip()

print(len(info_dic))



#id_list = ['HC01','HC03','HC04','HC05','HC06','HC08','HC09','HC10','HC12','HC13','HC16','HC17','HC18','HC19','HC20','HC21'] #'HC15'
id_list = ['HC14','HC15']

output_file = file("/home/users/jhyouk/14_colon_LINE1/53_early_embryonic_tree_bySYPark/59_run_sampleN_annot_HC1415s.sh","w")
for i in id_list:
    print i
    n=0
    for j in info_dic.keys():
        if i in j:
            n+=1
            
    output_file.write("python DB_AddSampleNinfo.py %s_merged.txt /home/users/jhyouk/14_colon_LINE1/03_mpileup/HC14_15_merged_mpileup/\
# %s.%ss.q20Q20.chr1.mpileup.snv.%sN.gz &> %s_sampleN_annot.log && mv %s_sampleN_annot.log %s_sampleN_annot.success\n" %(i,i,str(n),str(n),i,i,i))
output_file.close()
print 'THE END'
#python DB_AddSampleNinfo.py DB10_50s_merged.txt /home/users/sypark/00_Project/06_LineageTracing/db10/02_mpileup/01_merged_mpu_q20Q20/DB10.52s.q20Q20.chr1.mpileup.snv.50N.gz &> sampleN_annot.log && mv sampleN_annot.log sampleN_annot.success
# Out:
# 405
# HC14
# HC15
# THE END

# %%
## Extra2

import os,sys
#id_list = ['HC01','HC03','HC04','HC05','HC06','HC08','HC09','HC10','HC12','HC13','HC16','HC17','HC18','HC19','HC20','HC21'] #'HC15'
id_list = ['HC14','HC15']

info_file = file("/home/users/jhyouk/14_colon_LINE1/colon_LINE1_405_metadata_v2.txt")
info_line = info_file.readline().strip()
info_line = info_file.readline().strip()

info_dic = {}
while info_line:
    info_split = info_line.split('\t')
    info_dic[info_split[0]] = info_split[1]

    info_line = info_file.readline().strip()

print(len(info_dic))

for pt_num in id_list:
    print pt_num
    crypt_num = 0
    temp_list = os.listdir("/home/users/jhyouk/14_colon_LINE1/53_early_embryonic_tree_bySYPark")
    file_list = []
    pre_list = []
    for i in temp_list:
        if pt_num in i and '.VS_HC_common' in i and '.cmn_fi' not in i:
            pre_list.append(i)
    print len(pre_list)
    crypt_num = str(len(pre_list))
    #sys.exit(1)
    #for i in pre_list:
    #    print i

    #output_file = file("/home/users/jhyouk/14_colon_LINE1/03_mpileup/merged_mpileup/01_run.%s.%s.mpu.call.sh" %(pt_num,crypt_num),"w")
    bam_list = ''
    for input_fn in pre_list:
        input_id = input_fn.split('.')[0]
        bam_list = bam_list + '/home/users/team_projects/colon_LINE1/02_bam/'+ info_dic[input_id] + ' '
    #print bam_list
    #sys.exit(1)
    i=pt_num
    output_file = file("/home/users/jhyouk/14_colon_LINE1/03_mpileup/HC14_15_merged_mpileup/02_run_snv_mpu_counting_%s.sh" %i,"w")
    print i
    for j in range(1,26):
        j = str(j).replace("23","X").replace("24","Y").replace("25","MT")
        output_file.write("python %s_mpu_snv_sampleN_Dpmore10.py %s.%ss.q20Q20.chr%s.mpileup.snv.gz &> %s_chr%s.snv_count.log && \
mv %s_chr%s.snv_count.log %s_chr%s.snv_count.success\n" % (i,i,len(pre_list),str(j),i,str(j),i,str(j),i,str(j)))

    output_file.close()
print 'THE END'
# Out:
# 405
# HC14
# 19
# HC14
# HC15
# 23
# HC15
# THE END

# %%
#Extra3
temp = '/home/users/team_projects/colon_LINE1/02_bam/JHY-COL-HC14-05-wgs-ILLUMINA.fmarked.bam /home/users/team_projects/colon_LINE1/02_bam/JHY-COL-HC14-13-wgs-ILLUMINA.fmarked.bam /home/users/team_projects/colon_LINE1/02_bam/JHY-COL-HC14-08-wgs-ILLUMINA.fmarked.bam /home/users/team_projects/colon_LINE1/02_bam/JHY-COL-HC14-06-wgs-ILLUMINA.fmarked.bam /home/users/team_projects/colon_LINE1/02_bam/JHY-COL-HC14-16-wgs-ILLUMINA.fmarked.bam /home/users/team_projects/colon_LINE1/02_bam/JHY-COL-HC14-11-wgs-ILLUMINA.fmarked.bam /home/users/team_projects/colon_LINE1/02_bam/JHY-COL-HC14-09-wgs-ILLUMINA.fmarked.bam /home/users/team_projects/colon_LINE1/02_bam/JHY-COL-HC14-03-wgs-ILLUMINA.fmarked.bam /home/users/team_projects/colon_LINE1/02_bam/JHY-COL-HC14-02-wgs-ILLUMINA.fmarked.bam /home/users/team_projects/colon_LINE1/02_bam/JHY-COL-HC14-10-wgs-ILLUMINA.fmarked.bam /home/users/team_projects/colon_LINE1/02_bam/JHY-COL-HC14-19-wgs-ILLUMINA.fmarked.bam /home/users/team_projects/colon_LINE1/02_bam/JHY-COL-HC14-07-wgs-ILLUMINA.fmarked.bam /home/users/team_projects/colon_LINE1/02_bam/JHY-COL-HC14-12-wgs-ILLUMINA.fmarked.bam /home/users/team_projects/colon_LINE1/02_bam/JHY-COL-HC14-14-wgs-ILLUMINA.fmarked.bam /home/users/team_projects/colon_LINE1/02_bam/JHY-COL-HC14-01-wgs-ILLUMINA.fmarked.bam /home/users/team_projects/colon_LINE1/02_bam/JHY-COL-HC14-04-wgs-ILLUMINA.fmarked.bam /home/users/team_projects/colon_LINE1/02_bam/JHY-COL-HC14-17-wgs-ILLUMINA.fmarked.bam /home/users/team_projects/colon_LINE1/02_bam/JHY-COL-HC14-15-wgs-ILLUMINA.fmarked.bam /home/users/team_projects/colon_LINE1/02_bam/JHY-COL-HC14-18-wgs-ILLUMINA.fmarked.bam'
a = temp.split(' ')
b=[]
for i in a:
    b.append(i.split('/')[-1].replace("JHY-COL-","").replace("-wgs-ILLUMINA.fmarked.bam","").replace(".s.md.bam",""))
    
print len(b)
print b
# Out:
# 19
# ['HC14-05', 'HC14-13', 'HC14-08', 'HC14-06', 'HC14-16', 'HC14-11', 'HC14-09', 'HC14-03', 'HC14-02', 'HC14-10', 'HC14-19', 'HC14-07', 'HC14-12', 'HC14-14', 'HC14-01', 'HC14-04', 'HC14-17', 'HC14-15', 'HC14-18']

# %%
#Extra4 sequenza segment cleaning

import os,sys
temp_list = os.listdir("/home/users/jhyouk/14_colon_LINE1/04_sequenza_gender/")
file_list = []
pre_list = []
n=0
for i in temp_list:
    if ".100kbcov" not in i and ".gz" not in i and ".R" not in i and ".sh" not in i and ".py" not in i and '.ipynb' not in i:
        if "qsub" not in i:
            file_list.append(i)
            #print i
print len(file_list)
#sys.exit(1)
output_file = file("/home/users/jhyouk/14_colon_LINE1/04_sequenza_gender/51_run_segment_clean.sh","w")
for j in file_list:
    output_file.write("python seqz_segment_clear.py /home/users/jhyouk/14_colon_LINE1/04_sequenza_gender/%s/%s_segments.txt &> %s.out \n" % (j,j,j))

output_file.close()
print 'THE END'
# Out:
# 405
# THE END

# %%
#10
import os,sys
#id_list = ['HC01','HC15','HC03','HC04','HC05','HC06','HC08','HC09','HC10','HC12','HC13','HC14','HC16','HC17','HC18','HC19','HC20','HC21'] #'HC15'
id_list = ['HC14','HC15']
gender_list = ['F','F']

temp_list = os.listdir("/home/users/jhyouk/14_colon_LINE1/04_sequenza")
file_list = []

n=0
for i in temp_list:
    if ".100kbcov" not in i and ".gz" not in i and ".R" not in i and ".sh" not in i and ".py" not in i and '.ipynb' not in i:
        if "qsub" not in i:
            file_list.append(i)
            #print i
print len(file_list)
#sys.exit(1)

n=0
output_file = file("/home/users/jhyouk/14_colon_LINE1/53_early_embryonic_tree_bySYPark/60_run_loh_annot_HC1415.sh","w")
for id_fn in id_list:
    pre_list = []
    for j in file_list:
        if id_fn in j:
            pre_list.append(j)
    print len(pre_list)
    #sys.exit(1)

    # generate seqz_clean_list.txt
    output_file1 = file("/home/users/jhyouk/14_colon_LINE1/53_early_embryonic_tree_bySYPark/%s_seqz_clean_list.txt" %id_fn,"w")
    for ii in pre_list:
        output_file1.write("%s\t/home/users/jhyouk/14_colon_LINE1/04_sequenza_gender/%s/%s_segments.txt.clean\n" %(ii.replace("JHY-COL-","").replace("_blood-wgs-ILLUMINA.fmarked",""),ii,ii))   
    output_file1.close()
    output_file.write("python add_loh_samples.py %s_merged.txt.sampleN %s_seqz_clean_list.txt %s &> %s.60_run.out\n" %(id_fn,id_fn,gender_list[id_list.index(id_fn)],id_fn) )
    
    n+=1
output_file.close()
print 'THE END'
# Out:
# 405
# 19
# 23
# THE END

# %%
a={}
a['HC02']['1'] = 3
print a['HC02']['1']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-128-fce797d14fd5> in <module>()
#       1 a={}
# ----> 2 a['HC02']['1'] = 3
#       3 print a['HC02']['1']
#
# KeyError: 'HC02'

# %%
#Extra
#sequenza plot reconstruction with gender information

import os,sys
temp_list = os.listdir("/home/users/jhyouk/14_colon_LINE1/04_sequenza")
file_list = []

n=0
for i in temp_list:
    if ".100kbcov" not in i and ".gz" not in i and ".R" not in i and ".sh" not in i and ".py" not in i and '.ipynb' not in i:
        if "qsub" not in i:
            file_list.append(i)
print len(file_list)
#sys.exit(1)
            
            
id_list = ['HC01','HC03','HC04','HC05','HC06','HC08','HC09','HC10','HC12','HC13','HC14','HC15','HC16','HC17','HC18','HC19','HC20','HC21'] #'HC15'
gender_list = ['M','M','M','F','M','F','M','M','F','M','F','F','F','F','F','M','F','F']
#print len(id_list),len(gender_list)

#id_list = ['HC02']
#gender_list = ['M']
output_file=file("/home/users/jhyouk/14_colon_LINE1/04_sequenza_gender/01_run_pdf_gender_383.sh","w")
for id_fn in id_list:
    print id_fn
    k = gender_list[id_list.index(id_fn)]
    if k=='M':
        kk = 'XY'
    else:
        kk='XX'
    for j in file_list:
        if id_fn in j:
            if 'JHY-COL' in j:
                output_file.write("/home/users/kjyi/miniconda3/bin/Rscript ../04_sequenza/11_Rscript_sequenza_6args.R ../04_sequenza/%s.comp.seqz.rmGLMT.gz %s 1 2 hg19 %s &> %s.Rscript_gender.out\n" %(j,j,kk,j))
            else:
                output_file.write("/home/users/kjyi/miniconda3/bin/Rscript ../04_sequenza/11_Rscript_sequenza_6args.R ../04_sequenza/%s.comp.seqz.rmGLMTJH.gz %s 1 2 hg19 %s &> %s.Rscript_gender.out\n" %(j,j,kk,j))
                
output_file.close()
print 'THE END'
# Out:
# 405
# HC01
# HC03
# HC04
# HC05
# HC06
# HC08
# HC09
# HC10
# HC12
# HC13
# HC14
# HC15
# HC16
# HC17
# HC18
# HC19
# HC20
# HC21
# THE END

# %%
#11
info_file = file("/home/users/jhyouk/14_colon_LINE1/colon_LINE1_405_metadata_v2.txt")
info_line = info_file.readline().strip()
info_line = info_file.readline().strip()

info_dic = {}
while info_line:
    info_split = info_line.split('\t')
    info_dic[info_split[0]] = info_split[1]

    info_line = info_file.readline().strip()

print(len(info_dic))

#id_list = ['HC01','HC03','HC04','HC05','HC06','HC08','HC09','HC10','HC12','HC13','HC14','HC15','HC16','HC17','HC18','HC19','HC20','HC21'] #'HC15'
id_list = ['HC14','HC15']
output_file = file("/home/users/jhyouk/14_colon_LINE1/53_early_embryonic_tree_bySYPark/61_run_merged_germ_fi_HC1415.sh","w")

for id_fn in id_list:
    output_file1 = file("/home/users/jhyouk/14_colon_LINE1/53_early_embryonic_tree_bySYPark/%s_merge_input_ids.txt" % id_fn,"w")
    output_file2 = file("/home/users/jhyouk/14_colon_LINE1/53_early_embryonic_tree_bySYPark/%s_excluded_ids.txt" % id_fn,"w")
    for j in info_dic.keys():
        if id_fn in j:
            output_file1.write(j+'\n')
    
    output_file.write("python merged_germ_filter.py %s_merged.txt.sampleN.loh_id %s_merge_input_ids.txt %s_excluded_ids.txt\n" %(id_fn,id_fn,id_fn))
    output_file1.close()
    output_file2.close()
output_file.close()
print 'THE END'
# Out:
# 405
# THE END

# %%
#12
info_file = file("/home/users/jhyouk/14_colon_LINE1/colon_LINE1_405_metadata_v2.txt")
info_line = info_file.readline().strip()
info_line = info_file.readline().strip()

info_dic = {}
while info_line:
    info_split = info_line.split('\t')
    info_dic[info_split[0]] = info_split[1]

    info_line = info_file.readline().strip()

print(len(info_dic))

#id_list = ['HC01','HC03','HC04','HC05','HC06','HC08','HC09','HC10','HC12','HC13','HC14','HC15','HC16','HC17','HC18','HC19','HC20','HC21'] #'HC15'
id_list = ['HC14','HC15']
output_file = file("/home/users/jhyouk/14_colon_LINE1/53_early_embryonic_tree_bySYPark/62_run_sampling_for_HM_HC1415.sh","w")

for id_fn in id_list:
    n=0
    for j in info_dic.keys():
        if id_fn in j:
            n+=1
    print 'n=',n
    output_file.write("python shared_mt_sampling.py %s_merged.txt.sampleN.loh_id.g_fi %s 3\n" %(id_fn,str(n)))
    output_file.write("python shared_mt_sampling.py %s_merged.txt.sampleN.loh_id.g_fi %s 5\n" %(id_fn,str(n)))
    output_file.write("python shared_mt_sampling.py %s_merged.txt.sampleN.loh_id.g_fi %s 2\n" %(id_fn,str(n)))

output_file.close()
print 'THE END'
# Out:
# 405
# n= 19
# n= 23
# THE END

# %%
#13
info_file = file("/home/users/jhyouk/14_colon_LINE1/colon_LINE1_405_metadata_v2.txt")
info_line = info_file.readline().strip()
info_line = info_file.readline().strip()

info_dic = {}
while info_line:
    info_split = info_line.split('\t')
    info_dic[info_split[0]] = info_split[1]

    info_line = info_file.readline().strip()

print(len(info_dic))


#id_list = ['HC01','HC03','HC04','HC05','HC06','HC08','HC09','HC10','HC12','HC13','HC14','HC15','HC16','HC17','HC18','HC19','HC20','HC21'] #'HC15'
id_list = ['HC14','HC15']
output_file = file("/home/users/jhyouk/14_colon_LINE1/53_early_embryonic_tree_bySYPark/63_run_multibam_mpu_for_HM_HC1415.sh","w")

for id_fn in id_list:
    output_file1 = file("/home/users/jhyouk/14_colon_LINE1/53_early_embryonic_tree_bySYPark/%s_bam_list.txt" % id_fn,"w")
    output_file2 = file("/home/users/jhyouk/14_colon_LINE1/53_early_embryonic_tree_bySYPark/%s_bam_id_list.txt" % id_fn,"w")
    n=0
    for j in info_dic.keys():
        if id_fn in j:
            n+=1
            output_file1.write('/home/users/team_projects/colon_LINE1/02_bam/'+info_dic[j]+'\n')
            output_file2.write(j+'\n')
    print 'n=',n
    output_file1.close()
    output_file2.close()
    output_file.write("python DB_mpu_multibam_call_edit.py %s_merged.txt.sampleN.loh_id.g_fi.sam2.txt %s_bam_list.txt %s_bam_id_list.txt %s &> %s_mb_mpu.log && mv %s_mb_mpu.log %s_mb_mpu.success\n" %(id_fn,id_fn,id_fn,str(n),id_fn,id_fn,id_fn))
    output_file.write("python DB_mpu_multibam_call_edit.py %s_merged.txt.sampleN.loh_id.g_fi.sam3.txt %s_bam_list.txt %s_bam_id_list.txt %s &> %s_mb_mpu.log && mv %s_mb_mpu.log %s_mb_mpu.success\n" %(id_fn,id_fn,id_fn,str(n),id_fn,id_fn,id_fn))
    output_file.write("python DB_mpu_multibam_call_edit.py %s_merged.txt.sampleN.loh_id.g_fi.sam5.txt %s_bam_list.txt %s_bam_id_list.txt %s &> %s_mb_mpu.log && mv %s_mb_mpu.log %s_mb_mpu.success\n" %(id_fn,id_fn,id_fn,str(n),id_fn,id_fn,id_fn))

output_file.close()
print 'THE END'
# Out:
# 405
# n= 19
# n= 23
# THE END

# %%
#Extra to retrieve abn. CN samples
id_list = ['HC01','HC02','HC03','HC04','HC05','HC06','HC08','HC09','HC10','HC12','HC13','HC14','HC15','HC16','HC17','HC18','HC19','HC20','HC21'] #'HC15'
gender_list = ['M','M','M','M','F','M','F','M','M','F','M','F','F','F','F','F','M','F','F']


import os,sys
temp_list = os.listdir("/home/users/jhyouk/14_colon_LINE1/04_sequenza_gender/")
file_list = []
pre_list = []
n=0
for i in temp_list:
    if ".100kbcov" not in i and ".gz" not in i and ".R" not in i and ".sh" not in i and ".py" not in i and '.ipynb' not in i:
        if "qsub" not in i:
            file_list.append(i)
            #print i
print len(file_list)
#sys.exit(1)

for input_fn in file_list:
    input_file = file("/home/users/jhyouk/14_colon_LINE1/04_sequenza_gender/%s/%s_segments.txt.clean" % (input_fn,input_fn))
    temp_gender = ''
    temp=0
    for j in id_list:
        if j in input_fn:
            temp_gender = gender_list[id_list.index(j)]
            break
    if temp== 1:
        input_file.close()
        continue
    input_line = input_file.readline().strip()
    input_line = input_file.readline().strip()
    while input_line:
        input_split = input_line.split('\t')
        if temp_gender == 'F':
            if input_split[4] !='1' or input_split[5] != '1':
                print input_fn
                print input_line
                
            
        elif temp_gender == 'M':
            if input_split[0] == 'X' or input_split[0] == 'Y':
                if input_split[3] != '1':
                    print input_fn
                    print input_line
            else:
                if input_split[4] !='1' or input_split[5] != '1':
                    print input_fn
                    print input_line                
            
        else:
            print 'UNEXPECTED'
        input_line = input_file.readline().strip()
    input_file.close()

print 'THE END'
# Out:
# 405
# HC05-01
# 8	79078613	80305754	2	2	0
# JHY-COL-HC06-20_blood-wgs-ILLUMINA.fmarked
# Y	28806428	59033610	3	1	0
# JHY-COL-HC13-13_blood-wgs-ILLUMINA.fmarked
# 2	90532523	92325966	0	0	0
# JHY-COL-HC13-13_blood-wgs-ILLUMINA.fmarked
# Y	28784163	59033357	2	1	0
# HC19-09
# Y	28790987	59033375	2	1	0
# JHY-COL-HC10-03_blood-wgs-ILLUMINA.fmarked
# Y	28802898	59033610	3	1	0
# JHY-COL-HC13-18_blood-wgs-ILLUMINA.fmarked
# 2	89876953	92325966	3	2	1
# JHY-COL-HC06-18_blood-wgs-ILLUMINA.fmarked
# Y	23901106	59033610	2	1	0
# JHY-COL-HC10-08_blood-wgs-ILLUMINA.fmarked
# Y	28549246	59033610	2	1	0
# JHY-COL-HC04-21_blood-wgs-ILLUMINA.fmarked
# Y	28810391	59033610	2	1	0
# JHY-COL-HC04-04_blood-wgs-ILLUMINA.fmarked
# Y	28812934	59033610	3	1	0
# JHY-COL-HC08-16_blood-wgs-ILLUMINA.fmarked
# 2	90381963	92325966	4	3	1
# JHY-COL-HC19-20_blood-wgs-ILLUMINA.fmarked
# Y	28700764	59033375	2	1	0
# JHY-COL-HC10-12_blood-wgs-ILLUMINA.fmarked
# Y	28818558	59033610	2	1	0
# ...

# %%
#Extra to retrieve abn. CN samples
id_list = ['HC01','HC02','HC03','HC04','HC05','HC06','HC08','HC09','HC10','HC12','HC13','HC14','HC15','HC16','HC17','HC18','HC19','HC20','HC21'] #'HC15'
gender_list = ['M','M','M','M','F','M','F','M','M','F','M','F','F','F','F','F','M','F','F']


import os,sys
temp_list = os.listdir("/home/users/jhyouk/14_colon_LINE1/04_sequenza_gender/")
file_list = []
pre_list = []
n=0
for i in temp_list:
    if ".100kbcov" not in i and ".gz" not in i and ".R" not in i and ".sh" not in i and ".py" not in i and '.ipynb' not in i:
        if "qsub" not in i:
            file_list.append(i)
            #print i
print len(file_list)
#sys.exit(1)

for input_fn in file_list:
    input_file = file("/home/users/jhyouk/14_colon_LINE1/04_sequenza_gender/%s/%s_segments.txt" % (input_fn,input_fn))
    temp_gender = ''
    temp=0
    for j in id_list:
        if j in input_fn:
            temp_gender = gender_list[id_list.index(j)]
            break
    if temp== 1:
        input_file.close()
        continue
    input_line = input_file.readline().strip()
    input_line = input_file.readline().strip()
    while input_line:
        input_split = input_line.split('\t')
        if int(input_split[2]) - int(input_split[1]) > 100000:
            if float(input_split[6]) < 0.3:
                print input_fn
                print input_line
        input_line = input_file.readline().strip()
    input_file.close()

print 'THE END'
# Out:
# 405
# HC03-12
# "Y"	2932746	9908828	0.0377839274524644	252	0.0907239797140878	0.228412142651727	1804	0.330629526664721	1	NA	NA	-15.8484793895773
# HC03-12
# "Y"	13869877	21155023	0.0365654802990336	114	0.0884266331245188	0.169359215904889	989	0.228355900471977	1	NA	NA	-19.233847560011
# HC03-12
# "Y"	22225604	23901231	0.0222963288521193	91	0.0897697502425403	0.0520302137619866	444	0.0256115809532607	1	NA	NA	-30.9764758745962
# HC03-12
# "Y"	28805301	58905551	0.158932282002784	181	0.177278277811797	0.0217065356360928	564	0.0266487826290507	1	NA	NA	-40.9572028945365
# THE END
